# %% [markdown]
# # Session 4:  Basics of Data Analysis with Python

# %% [markdown]
# # this is a heading
#
# ## this is a smaller heading
#
# 1. this is a list
# 2. this is a list
#
#
# * this is a bulleted list
# * so is this
#
#
# ![this is a link]("\link_to_a_file")
#
# [this is a link](https://www.google.com)
#
#
# <h1>heading</h1>

# %% [markdown]
# ## Objectives
#
# Learn how to conduct basic data analysis using Pandas, an open source data analysis and manipulation tool built on the Python programming language

# %% [markdown]
# ## Agenda
#
# Topic recap & Pandas demonstration (60 mins.)
# Discussion of the Python Portfolio Project (30 mins.)

# %% [markdown]
# ## What is Pandas?
#
# * Python Data Analysis Library
# * Python library with a set of tools for data analysis
# * load, prepare, manipulate, model, analyze, merge, reshape, etc
# * data frame - the basic structure (like a table)
# * ```import pandas as pd```

# %%
import pandas as pd

# %% [markdown]
# ## What is a DataFrame?
#
# Features of DataFrame
# * Labeled axes (rows and columns)
# * Potentially columns are of different types
# * Size is mutable
# * Can perform arithmetic operations on rows and columns
# * Can slice, select, index, etc

# %% [markdown]
# ## Loading and Reading Data
#
# * Reading Data
# ```
# df = pd.read_csv(csv_path)
# df = pd.read_excel(excel_path)
# ```
# * Displaying Data
# ```
# df.head(n) - shows the top n rows (default is 5)
# df.tail(n) - shows the last n rows (default is 5)
# df.T - transpose rows and columns
# ```

# %%
df = pd.read_csv('inventory.csv')

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.head(10)
# Out:
#         location  product_type         product_description  quantity  price
# 0  Staten Island         seeds                       daisy         4   6.99
# 1  Staten Island         seeds                  calla lily        46  19.99
# 2  Staten Island         seeds                      tomato        85  13.99
# 3  Staten Island  garden tools                        rake         4  13.99
# 4  Staten Island  garden tools                 wheelbarrow         0  89.99
# 5  Staten Island  garden tools                       spade        93  19.99
# 6  Staten Island  pest_control               insect killer        74  12.99
# 7  Staten Island  pest_control                 weed killer         8  23.99
# 8  Staten Island       planter  20 inch terracotta planter         0  17.99
# 9  Staten Island       planter      8 inch plastic planter        53   3.99

# %%
df.tail()
# Out:
#    location  product_type         product_description  quantity  price
# 24   Queens  garden tools                 wheelbarrow        98  89.99
# 25   Queens  garden tools                       spade        26  19.99
# 26   Queens  pest_control               insect killer         0  12.99
# 27   Queens  pest_control                 weed killer        16  23.99
# 28   Queens       planter  20 inch terracotta planter        87  17.99

# %%
df.T
# transpose switch rows and columns.  I didn't save this to a variable so not going to stick
# Out:
#                                 0              1              2   \
# location             Staten Island  Staten Island  Staten Island
# product_type                 seeds          seeds          seeds
# product_description          daisy     calla lily         tomato
# quantity                         4             46             85
# price                         6.99          19.99          13.99
#
#                                 3              4              5   \
# location             Staten Island  Staten Island  Staten Island
# product_type          garden tools   garden tools   garden tools
# product_description           rake    wheelbarrow          spade
# quantity                         4              0             93
# price                        13.99          89.99          19.99
#
#                                 6              7                           8   \
# location             Staten Island  Staten Island               Staten Island
# product_type          pest_control   pest_control                     planter
# product_description  insect killer    weed killer  20 inch terracotta planter
# quantity                        74              8                           0
# price                        12.99          23.99                       17.99
#
#                                          9   ...                      19  \
# location                      Staten Island  ...                Brooklyn
# product_type                        planter  ...                 planter
# product_description  8 inch plastic planter  ...  8 inch plastic planter
# quantity                                 53  ...                      26
# price                                  3.99  ...                    3.99
#
#                          20          21      22            23            24  \
# location             Queens      Queens  Queens        Queens        Queens
# product_type          seeds       seeds   seeds  garden tools  garden tools
# product_description   daisy  calla lily  tomato          rake   wheelbarrow
# quantity                 57          95      45            21            98
# price                  6.99       19.99   13.99         13.99         89.99
#
#                                25             26            27  \
# location                   Queens         Queens        Queens
# product_type         garden tools   pest_control  pest_control
# product_description         spade  insect killer   weed killer
# quantity                       26              0            16
# price                       19.99          12.99         23.99
#
#                                              28
# location                                 Queens
# product_type                            planter
# product_description  20 inch terracotta planter
# quantity                                     87
# price                                     17.99
#
# [5 rows x 29 columns]

# %%
print(type(df))
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
#         location  product_type product_description  quantity  price
# 0  Staten Island         seeds               daisy         4   6.99
# 1  Staten Island         seeds          calla lily        46  19.99
# 2  Staten Island         seeds              tomato        85  13.99
# 3  Staten Island  garden tools                rake         4  13.99
# 4  Staten Island  garden tools         wheelbarrow         0  89.99

# %% [markdown]
# ## Summarizing Data
#
# * shape - shows number of rows and columns
# * ndim - number of axes/array dimensions
# * size - number of rows * number of columns
# * empty - true if the dataframe is empty
# * axes - a list of the row axis labels and column axis labels

# %%
df.shape

#rows , columns
# Out:
# (29, 5)

# %%
df.ndim

# number of dimensions (x,y)
# Out:
# 2

# %%
df.size

# length x width
# Out:
# 145

# %%
df.empty

# df is not empty
# Out:
# False

# %%
df.axes

# returns a list with the row axis labels, and the column axis labels, in that order.
# Out:
# [RangeIndex(start=0, stop=29, step=1),
#  Index(['location', 'product_type', 'product_description', 'quantity', 'price'], dtype='object')]

# %% [markdown]
# ## Descriptive Statistics
#
# * ```df.sum()``` - totals each individual column (strings are appended)
# * ```df.mean()``` - returns the average value of numeric columns
# * ```df.std()``` - returns the standard deviation of numeric columns
# * ```df.describe()``` - returns a complete table of summary statistics (mean, std, min, max, quartiles)
# * ```df.median()``` - returns the median of values

# %%
df.sum()

# a specific column is not given so will compute sum of all the columns
# Out:
# location               Staten IslandStaten IslandStaten IslandStaten ...
# product_type           seedsseedsseedsgarden toolsgarden toolsgarden ...
# product_description    daisycalla lilytomatorakewheelbarrowspadeinsec...
# quantity                                                            1182
# price                                                             667.71
# dtype: object

# %%
df.mean()
# Out:
# /var/folders/f6/39wzptds0jx4g4sr7kpl16c00000gn/T/ipykernel_13164/3698961737.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.mean()
# quantity    40.758621
# price       23.024483
# dtype: float64

# %%
df['price'].mean()
# Out:
# 23.024482758620696

# %%
df['quantity'].std()
# Out:
# 35.18385909599314

# %%
df.describe()

# summary of descriptive statistics
# Out:
#         quantity      price
# count  29.000000  29.000000
# mean   40.758621  23.024483
# std    35.183859  23.810986
# min     0.000000   3.990000
# 25%     5.000000  12.990000
# 50%    36.000000  17.990000
# 75%    76.000000  19.990000
# max    98.000000  89.990000

# %%
df.median()
# Out:
# /var/folders/f6/39wzptds0jx4g4sr7kpl16c00000gn/T/ipykernel_13164/530051474.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.median()
# quantity    36.00
# price       17.99
# dtype: float64

# %% [markdown]
# ## Sorting
#
# * df.sort_index(axis, ascending)
#     * axis - 0 sort by row (default), 1 sort by column
#     * ascending - True sort ascending, False sort descending

# %%
data = {'Product': ['Computer','Printer','Monitor','Desk','Phone','Tablet','Scanner'],
          'Price': [1100,150,500,350,100,300,120]
        }

df2 = pd.DataFrame(data, columns = ['Product','Price'])

df2
# Out:
#     Product  Price
# 0  Computer   1100
# 1   Printer    150
# 2   Monitor    500
# 3      Desk    350
# 4     Phone    100
# 5    Tablet    300
# 6   Scanner    120

# %%
df2.sort_index()
# Out:
#          Product  Price
# Item_A   Monitor    500
# Item_B   Printer    150
# Item_C      Desk    350
# Item_D  Computer   1100
# Item_E   Scanner    120
# Item_F     Phone    100
# Item_G    Tablet    300

# %%
df2.sort_index(ascending = False)
# Out:
#     Product  Price
# 6   Scanner    120
# 5    Tablet    300
# 4     Phone    100
# 3      Desk    350
# 2   Monitor    500
# 1   Printer    150
# 0  Computer   1100

# %% [markdown]
# By default, the index is sorted in an ascending order:
#
#
# Let’s replace the default index values with the following unsorted values:

# %%
index = ['Item_D','Item_B','Item_A','Item_C','Item_F','Item_G','Item_E']

# %%
data = {'Product': ['Computer','Printer','Monitor','Desk','Phone','Tablet','Scanner'],
          'Price': [1100,150,500,350,100,300,120]
        }

df2 = pd.DataFrame(data, columns = ['Product','Price'], index = ['Item_D','Item_B','Item_A','Item_C','Item_F','Item_G','Item_E'])

df2
# Out:
#          Product  Price
# Item_D  Computer   1100
# Item_B   Printer    150
# Item_A   Monitor    500
# Item_C      Desk    350
# Item_F     Phone    100
# Item_G    Tablet    300
# Item_E   Scanner    120

# %%
df2.sort_index()
# Out:
#          Product  Price
# Item_A   Monitor    500
# Item_B   Printer    150
# Item_C      Desk    350
# Item_D  Computer   1100
# Item_E   Scanner    120
# Item_F     Phone    100
# Item_G    Tablet    300

# %% [markdown]
# ## Selection
#
# Will automatically include the index column
#
# One column selected with the index is called a series

# %%
df.head(5)
# Out:
#         location  product_type product_description  quantity  price
# 0  Staten Island         seeds               daisy         4   6.99
# 1  Staten Island         seeds          calla lily        46  19.99
# 2  Staten Island         seeds              tomato        85  13.99
# 3  Staten Island  garden tools                rake         4  13.99
# 4  Staten Island  garden tools         wheelbarrow         0  89.99

# %%
df['product_type']
# Out:
# 0            seeds
# 1            seeds
# 2            seeds
# 3     garden tools
# 4     garden tools
# 5     garden tools
# 6     pest_control
# 7     pest_control
# 8          planter
# 9          planter
# 10           seeds
# 11           seeds
# 12           seeds
# 13    garden tools
# 14    garden tools
# 15    garden tools
# 16    pest_control
# 17    pest_control
# 18         planter
# 19         planter
# 20           seeds
# 21           seeds
# 22           seeds
# 23    garden tools
# 24    garden tools
# 25    garden tools
# 26    pest_control
# 27    pest_control
# 28         planter
# Name: product_type, dtype: object

# %%
df.head()
# Out:
#         location  product_type product_description  quantity  price
# 0  Staten Island         seeds               daisy         4   6.99
# 1  Staten Island         seeds          calla lily        46  19.99
# 2  Staten Island         seeds              tomato        85  13.99
# 3  Staten Island  garden tools                rake         4  13.99
# 4  Staten Island  garden tools         wheelbarrow         0  89.99

# %% [markdown]
# ## Selection by Label

# %%
df[['location','product_type']]

# Why double brackets???   because the standard selection notation is []  and then we are putting a list inside 
# of those brackets....so now we have [[]]
# Out:
#          location  product_type
# 0   Staten Island         seeds
# 1   Staten Island         seeds
# 2   Staten Island         seeds
# 3   Staten Island  garden tools
# 4   Staten Island  garden tools
# 5   Staten Island  garden tools
# 6   Staten Island  pest_control
# 7   Staten Island  pest_control
# 8   Staten Island       planter
# 9   Staten Island       planter
# 10       Brooklyn         seeds
# 11       Brooklyn         seeds
# 12       Brooklyn         seeds
# 13       Brooklyn  garden tools
# 14       Brooklyn  garden tools
# 15       Brooklyn  garden tools
# 16       Brooklyn  pest_control
# 17       Brooklyn  pest_control
# 18       Brooklyn       planter
# 19       Brooklyn       planter
# 20         Queens         seeds
# 21         Queens         seeds
# 22         Queens         seeds
# 23         Queens  garden tools
# 24         Queens  garden tools
# 25         Queens  garden tools
# 26         Queens  pest_control
# 27         Queens  pest_control
# 28         Queens       planter

# %% [markdown]
# ## Sort the Index in an Ascending Order in Pandas DataFrame
#
# In order to sort the index in an ascending order, you’ll need to add the following syntax to the code:

# %%
df2 = df2.sort_index()
print(df2)
# Out:
#          Product  Price
# Item_A   Monitor    500
# Item_B   Printer    150
# Item_C      Desk    350
# Item_D  Computer   1100
# Item_E   Scanner    120
# Item_F     Phone    100
# Item_G    Tablet    300

# %%
df2 = df2.sort_index(ascending=False)
print(df2)
# Out:
#          Product  Price
# Item_G    Tablet    300
# Item_F     Phone    100
# Item_E   Scanner    120
# Item_D  Computer   1100
# Item_C      Desk    350
# Item_B   Printer    150
# Item_A   Monitor    500

# %% [markdown]
# ## Indexing and Selecting and Slicing
#
#
# * Label Based - ```df.loc```
# * Integer Based - ```df.iloc```
#
#
# Use Text
# ```
# df.loc[row_start:row_end, [column_start, column_end]]
# ```
#
#
# Use Numbers
# ```
# df.iloc[row_start:row_end, [column_start, column_end]]
# ```
#
# Note: in pandas version > = 0.20.0, ix is deprecated . Thus, useloc and iloc instead.

# %%
df.head(5)
# Out:
#         location  product_type product_description  quantity  price
# 0  Staten Island         seeds               daisy         4   6.99
# 1  Staten Island         seeds          calla lily        46  19.99
# 2  Staten Island         seeds              tomato        85  13.99
# 3  Staten Island  garden tools                rake         4  13.99
# 4  Staten Island  garden tools         wheelbarrow         0  89.99

# %%
df.loc[0]
# Out:
# location               Staten Island
# product_type                   seeds
# product_description            daisy
# quantity                           4
# price                           6.99
# Name: 0, dtype: object

# %%
df.iloc[0]
# Out:
# location               Staten Island
# product_type                   seeds
# product_description            daisy
# quantity                           4
# price                           6.99
# Name: 0, dtype: object

# %%
df2
# Out:
#          Product  Price
# Item_G    Tablet    300
# Item_F     Phone    100
# Item_E   Scanner    120
# Item_D  Computer   1100
# Item_C      Desk    350
# Item_B   Printer    150
# Item_A   Monitor    500

# %%
df2.iloc[0]
# Out:
# Product    Tablet
# Price         300
# Name: Item_G, dtype: object

# %%
df2.loc['Item_D']
# Out:
# Product    Computer
# Price          1100
# Name: Item_D, dtype: object

# %%
df.iloc[0:3]
# Out:
#         location product_type product_description  quantity  price
# 0  Staten Island        seeds               daisy         4   6.99
# 1  Staten Island        seeds          calla lily        46  19.99
# 2  Staten Island        seeds              tomato        85  13.99

# %%
df2.loc['Item_D':'Item_G']
df2.iloc[0:3]
# Out:
#         Product  Price
# Item_G   Tablet    300
# Item_F    Phone    100
# Item_E  Scanner    120

# %%
df.iloc[-1]
# Out:
# location                                   Queens
# product_type                              planter
# product_description    20 inch terracotta planter
# quantity                                       87
# price                                       17.99
# Name: 28, dtype: object

# %% [markdown]
# ### Second argument is column selection

# %%
df.loc[0:4,['location']]
# Out:
#         location
# 0  Staten Island
# 1  Staten Island
# 2  Staten Island
# 3  Staten Island
# 4  Staten Island

# %%
df2
# Out:
#          Product  Price
# Item_G    Tablet    300
# Item_F     Phone    100
# Item_E   Scanner    120
# Item_D  Computer   1100
# Item_C      Desk    350
# Item_B   Printer    150
# Item_A   Monitor    500

# %%
df2.loc['Item_D':'Item_G',["Product", 'Price']]
# Out:
# Empty DataFrame
# Columns: [Product, Price]
# Index: []

# %%
df.head(5)
# Out:
#         location  product_type product_description  quantity  price
# 0  Staten Island         seeds               daisy         4   6.99
# 1  Staten Island         seeds          calla lily        46  19.99
# 2  Staten Island         seeds              tomato        85  13.99
# 3  Staten Island  garden tools                rake         4  13.99
# 4  Staten Island  garden tools         wheelbarrow         0  89.99

# %%
df.iloc[2:5, [2]]
# Out:
#   product_description
# 2              tomato
# 3                rake
# 4         wheelbarrow

# %%
df.loc[1:3, ['product_type', 'price']]
# Out:
#    product_type  price
# 1         seeds  19.99
# 2         seeds  13.99
# 3  garden tools  13.99

# %% [markdown]
# ## Grouping

# %%
ipl_data = {'Team': ['Riders', 'Riders', 'Devils', 'Devils', 'Kings', 'kings','Kings', 
                     'Kings', 'Riders', 'Royals', 'Royals','Riders' ], 'Rank':[1,2,2,3,3,4,1,1,2,4,1,2], 
           'Year':[2014, 2015, 2014, 2015, 2014,2015,2016,2017,2016,2014,2015,2017],'Points':[876,789,
                                                                                             863,673,741,812,756,788,694,701,
                                                                                             804,690]}

# this is a python dictionary. we will convert to dataframe in the next step

# %%
ipl_df = pd.DataFrame(ipl_data)

# %%
ipl_df.head()
# Out:
#      Team  Rank  Year  Points
# 0  Riders     1  2014     876
# 1  Riders     2  2015     789
# 2  Devils     2  2014     863
# 3  Devils     3  2015     673
# 4   Kings     3  2014     741

# %%
grouped = ipl_df.groupby('Year')

# %%
print(grouped)
# Out:
# <pandas.core.groupby.generic.DataFrameGroupBy object at 0x7f7cc839adc0>

# %%
for name, group in grouped:
    print(name)
# Out:
# 2014
# 2015
# 2016
# 2017

# %%
for name, group in grouped:
    print(group)
# Out:
#      Team  Rank  Year  Points
# 0  Riders     1  2014     876
# 2  Devils     2  2014     863
# 4   Kings     3  2014     741
# 9  Royals     4  2014     701
#       Team  Rank  Year  Points
# 1   Riders     2  2015     789
# 3   Devils     3  2015     673
# 5    kings     4  2015     812
# 10  Royals     1  2015     804
#      Team  Rank  Year  Points
# 6   Kings     1  2016     756
# 8  Riders     2  2016     694
#       Team  Rank  Year  Points
# 7    Kings     1  2017     788
# 11  Riders     2  2017     690

# %%
for name, group in grouped:
    print(name)
    print(group)
# Out:
# 2014
#      Team  Rank  Year  Points
# 0  Riders     1  2014     876
# 2  Devils     2  2014     863
# 4   Kings     3  2014     741
# 9  Royals     4  2014     701
# 2015
#       Team  Rank  Year  Points
# 1   Riders     2  2015     789
# 3   Devils     3  2015     673
# 5    kings     4  2015     812
# 10  Royals     1  2015     804
# 2016
#      Team  Rank  Year  Points
# 6   Kings     1  2016     756
# 8  Riders     2  2016     694
# 2017
#       Team  Rank  Year  Points
# 7    Kings     1  2017     788
# 11  Riders     2  2017     690

# %%
df.head()
# Out:
#         location  product_type product_description  quantity  price
# 0  Staten Island         seeds               daisy         4   6.99
# 1  Staten Island         seeds          calla lily        46  19.99
# 2  Staten Island         seeds              tomato        85  13.99
# 3  Staten Island  garden tools                rake         4  13.99
# 4  Staten Island  garden tools         wheelbarrow         0  89.99

# %%
g = df.groupby('product_type')

# %%
for labels,data in g:
    print(labels)
    print(data)
# Out:
# garden tools
#          location  product_type product_description  quantity  price
# 3   Staten Island  garden tools                rake         4  13.99
# 4   Staten Island  garden tools         wheelbarrow         0  89.99
# 5   Staten Island  garden tools               spade        93  19.99
# 13       Brooklyn  garden tools                rake        15  13.99
# 14       Brooklyn  garden tools         wheelbarrow        82  89.99
# 15       Brooklyn  garden tools               spade        36  19.99
# 23         Queens  garden tools                rake        21  13.99
# 24         Queens  garden tools         wheelbarrow        98  89.99
# 25         Queens  garden tools               spade        26  19.99
# pest_control
#          location  product_type product_description  quantity  price
# 6   Staten Island  pest_control       insect killer        74  12.99
# 7   Staten Island  pest_control         weed killer         8  23.99
# 16       Brooklyn  pest_control       insect killer        80  12.99
# 17       Brooklyn  pest_control         weed killer        76  23.99
# 26         Queens  pest_control       insect killer         0  12.99
# 27         Queens  pest_control         weed killer        16  23.99
# planter
#          location product_type         product_description  quantity  price
# 8   Staten Island      planter  20 inch terracotta planter         0  17.99
# 9   Staten Island      planter      8 inch plastic planter        53   3.99
# 18       Brooklyn      planter  20 inch terracotta planter         5  17.99
# 19       Brooklyn      planter      8 inch plastic planter        26   3.99
# 28         Queens      planter  20 inch terracotta planter        87  17.99
# seeds
#          location product_type product_description  quantity  price
# 0   Staten Island        seeds               daisy         4   6.99
# 1   Staten Island        seeds          calla lily        46  19.99
# 2   Staten Island        seeds              tomato        85  13.99
# 10       Brooklyn        seeds               daisy        50   6.99
# 11       Brooklyn        seeds          calla lily         0  19.99
# 12       Brooklyn        seeds              tomato         0  13.99
# 20         Queens        seeds               daisy        57   6.99
# 21         Queens        seeds          calla lily        95  19.99
# 22         Queens        seeds              tomato        45  13.99

# %% [markdown]
# ## Importing Data

# %%
salary_df = pd.read_excel('salary.xlsx', index_col=0)

# %%
salary_df.head()
# Out:
#                  Unnamed: 1           Unnamed: 2 Unnamed: 3 Unnamed: 4
# inventory
# location       product_type  product_description   quantity      price
# Staten Island         seeds                daisy          4       6.99
# Staten Island         seeds           calla lily         46      19.99
# Staten Island         seeds               tomato         85      13.99
# Staten Island  garden tools                 rake          4      13.99

# %%
salary_df = pd.read_excel('salary2.xlsx')
salary_df
# salary_df.columns = ['location', 'product_type', 'product_description', 'quantity', 'price']
# Out:
#          location  product_type         product_description  quantity  price
# 0   Staten Island         seeds                       daisy         4   6.99
# 1   Staten Island         seeds                  calla lily        46  19.99
# 2   Staten Island         seeds                      tomato        85  13.99
# 3   Staten Island  garden tools                        rake         4  13.99
# 4   Staten Island  garden tools                 wheelbarrow         0  89.99
# 5   Staten Island  garden tools                       spade        93  19.99
# 6   Staten Island  pest_control               insect killer        74  12.99
# 7   Staten Island  pest_control                 weed killer         8  23.99
# 8   Staten Island       planter  20 inch terracotta planter         0  17.99
# 9   Staten Island       planter      8 inch plastic planter        53   3.99
# 10       Brooklyn         seeds                       daisy        50   6.99
# 11       Brooklyn         seeds                  calla lily         0  19.99
# 12       Brooklyn         seeds                      tomato         0  13.99
# 13       Brooklyn  garden tools                        rake        15  13.99
# 14       Brooklyn  garden tools                 wheelbarrow        82  89.99
# 15       Brooklyn  garden tools                       spade        36  19.99
# 16       Brooklyn  pest_control               insect killer        80  12.99
# 17       Brooklyn  pest_control                 weed killer        76  23.99
# 18       Brooklyn       planter  20 inch terracotta planter         5  17.99
# 19       Brooklyn       planter      8 inch plastic planter        26   3.99
# 20         Queens         seeds                       daisy        57   6.99
# 21         Queens         seeds                  calla lily        95  19.99
# 22         Queens         seeds                      tomato        45  13.99
# 23         Queens  garden tools                        rake        21  13.99
# 24         Queens  garden tools                 wheelbarrow        98  89.99
# 25         Queens  garden tools                       spade        26  19.99
# 26         Queens  pest_control               insect killer         0  12.99
# 27         Queens  pest_control                 weed killer        16  23.99
# 28         Queens       planter  20 inch terracotta planter        87  17.99

# %%
salary_df.head()
salary_df.reset_index()
# Out:
#     index       location  product_type         product_description  quantity  \
# 0       0  Staten Island         seeds                       daisy         4
# 1       1  Staten Island         seeds                  calla lily        46
# 2       2  Staten Island         seeds                      tomato        85
# 3       3  Staten Island  garden tools                        rake         4
# 4       4  Staten Island  garden tools                 wheelbarrow         0
# 5       5  Staten Island  garden tools                       spade        93
# 6       6  Staten Island  pest_control               insect killer        74
# 7       7  Staten Island  pest_control                 weed killer         8
# 8       8  Staten Island       planter  20 inch terracotta planter         0
# 9       9  Staten Island       planter      8 inch plastic planter        53
# 10     10       Brooklyn         seeds                       daisy        50
# 11     11       Brooklyn         seeds                  calla lily         0
# 12     12       Brooklyn         seeds                      tomato         0
# 13     13       Brooklyn  garden tools                        rake        15
# 14     14       Brooklyn  garden tools                 wheelbarrow        82
# 15     15       Brooklyn  garden tools                       spade        36
# 16     16       Brooklyn  pest_control               insect killer        80
# 17     17       Brooklyn  pest_control                 weed killer        76
# 18     18       Brooklyn       planter  20 inch terracotta planter         5
# 19     19       Brooklyn       planter      8 inch plastic planter        26
# 20     20         Queens         seeds                       daisy        57
# 21     21         Queens         seeds                  calla lily        95
# 22     22         Queens         seeds                      tomato        45
# 23     23         Queens  garden tools                        rake        21
# 24     24         Queens  garden tools                 wheelbarrow        98
# 25     25         Queens  garden tools                       spade        26
# 26     26         Queens  pest_control               insect killer         0
# 27     27         Queens  pest_control                 weed killer        16
# 28     28         Queens       planter  20 inch terracotta planter        87
#
#     price
# 0    6.99
# 1   19.99
# 2   13.99
# 3   13.99
# 4   89.99
# 5   19.99
# 6   12.99
# 7   23.99
# 8   17.99
# 9    3.99
# 10   6.99
# 11  19.99
# 12  13.99
# 13  13.99
# 14  89.99
# 15  19.99
# 16  12.99
# 17  23.99
# 18  17.99
# 19   3.99
# 20   6.99
# 21  19.99
# 22  13.99
# 23  13.99
# 24  89.99
# 25  19.99
# 26  12.99
# 27  23.99
# 28  17.99

# %%
df = pd.read_csv('inventory.csv')

# %%
df.head()
# Out:
#         location  product_type product_description  quantity  price
# 0  Staten Island         seeds               daisy         4   6.99
# 1  Staten Island         seeds          calla lily        46  19.99
# 2  Staten Island         seeds              tomato        85  13.99
# 3  Staten Island  garden tools                rake         4  13.99
# 4  Staten Island  garden tools         wheelbarrow         0  89.99

# %% [markdown]
# ## Loading from SQL
#
# ```
# import pyodbc
# import pandas as pd
#
# cnxn = pyodbc.connect('DRIVER=ODBC Driver 17 for SQLServer; SERVER=servername/IP;DATABASE=somedatabase;UID=login;PWD=abc123@4556’)
#
# query = "SELECT top 10 facility FROM dba.tb_facility;"
# df = pd.read_sql(query, cnxn)
# print(df)
#
#
#
# ```

# %% [markdown]
# ## Making a DataFrame from a Python Dictionary

# %%
d = {'col1': [1, 2], 'col2': [3, 4]}
df3 = pd.DataFrame(data=d)
df3
# Out:
#    col1  col2
# 0     1     3
# 1     2     4

# %% [markdown]
# ## Descriptive Statistics

# %%
d = {'Name':pd.Series(['Tom','James','Ricky','Vin','Steve','Smith','Jack',
   'Lee','David','Gasper','Betina','Andres']),
   'Age':pd.Series([25,26,25,23,30,29,23,34,40,30,51,46]),
   'Rating':pd.Series([4.23,3.24,3.98,2.56,3.20,4.6,3.8,3.78,2.98,4.80,4.10,3.65])
}

#Create a DataFrame
df4 = pd.DataFrame(d)
df4.std()
# Out:
# /var/folders/f6/39wzptds0jx4g4sr7kpl16c00000gn/T/ipykernel_13164/3035605900.py:9: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df4.std()
# Age       9.232682
# Rating    0.661628
# dtype: float64

# %% [markdown]
# ## Functions
#
# ```
# 1	count()	Number of non-null observations
# 2	sum()	Sum of values
# 3	mean()	Mean of Values
# 4	median()	Median of Values
# 5	mode()	Mode of values
# 6	std()	Standard Deviation of the Values
# 7	min()	Minimum Value
# 8	max()	Maximum Value
# 9	abs()	Absolute Value
# 10	prod()	Product of Values
# 11	cumsum()	Cumulative Sum
# 12	cumprod()	Cumulative Product
# ```

# %%
df.head(5)
# Out:
#         location  product_type product_description  quantity  price
# 0  Staten Island         seeds               daisy         4   6.99
# 1  Staten Island         seeds          calla lily        46  19.99
# 2  Staten Island         seeds              tomato        85  13.99
# 3  Staten Island  garden tools                rake         4  13.99
# 4  Staten Island  garden tools         wheelbarrow         0  89.99

# %%
mean_cum_sum = df['quantity'].cumsum().mean()
mean_cum_sum
# Out:
# 572.1034482758621

# %%
df
# Out:
#          location  product_type         product_description  quantity  price
# 0   Staten Island         seeds                       daisy         4   6.99
# 1   Staten Island         seeds                  calla lily        46  19.99
# 2   Staten Island         seeds                      tomato        85  13.99
# 3   Staten Island  garden tools                        rake         4  13.99
# 4   Staten Island  garden tools                 wheelbarrow         0  89.99
# 5   Staten Island  garden tools                       spade        93  19.99
# 6   Staten Island  pest_control               insect killer        74  12.99
# 7   Staten Island  pest_control                 weed killer         8  23.99
# 8   Staten Island       planter  20 inch terracotta planter         0  17.99
# 9   Staten Island       planter      8 inch plastic planter        53   3.99
# 10       Brooklyn         seeds                       daisy        50   6.99
# 11       Brooklyn         seeds                  calla lily         0  19.99
# 12       Brooklyn         seeds                      tomato         0  13.99
# 13       Brooklyn  garden tools                        rake        15  13.99
# 14       Brooklyn  garden tools                 wheelbarrow        82  89.99
# 15       Brooklyn  garden tools                       spade        36  19.99
# 16       Brooklyn  pest_control               insect killer        80  12.99
# 17       Brooklyn  pest_control                 weed killer        76  23.99
# 18       Brooklyn       planter  20 inch terracotta planter         5  17.99
# 19       Brooklyn       planter      8 inch plastic planter        26   3.99
# 20         Queens         seeds                       daisy        57   6.99
# 21         Queens         seeds                  calla lily        95  19.99
# 22         Queens         seeds                      tomato        45  13.99
# 23         Queens  garden tools                        rake        21  13.99
# 24         Queens  garden tools                 wheelbarrow        98  89.99
# 25         Queens  garden tools                       spade        26  19.99
# 26         Queens  pest_control               insect killer         0  12.99
# 27         Queens  pest_control                 weed killer        16  23.99
# 28         Queens       planter  20 inch terracotta planter        87  17.99

# %% [markdown]
# ## Visualization
#
# * bar or barh for bar plots
# * hist for histogram
# * box for boxplot
# * 'area' for area plots
# * 'scatter' for scatter plots

# %%
df.head()
# Out:
#         location  product_type product_description  quantity  price
# 0  Staten Island         seeds               daisy         4   6.99
# 1  Staten Island         seeds          calla lily        46  19.99
# 2  Staten Island         seeds              tomato        85  13.99
# 3  Staten Island  garden tools                rake         4  13.99
# 4  Staten Island  garden tools         wheelbarrow         0  89.99

# %%
df['price'].plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df.plot.scatter(x= 'price', y = 'quantity')
# Out:
# <AxesSubplot:xlabel='price', ylabel='quantity'>

# %%
import numpy as np

df5 = pd.DataFrame(np.random.rand(10, 4),columns=['Steve_grades','Matt_grades','Mary_grades','John_grades'])
df5
# Out:
#    Steve_grades  Matt_grades  Mary_grades  John_grades
# 0      0.170812     0.703266     0.586390     0.297733
# 1      0.021254     0.266242     0.116099     0.633609
# 2      0.991361     0.820583     0.834560     0.347938
# 3      0.841099     0.441773     0.902524     0.684291
# 4      0.597819     0.432780     0.178688     0.988675
# 5      0.986419     0.237352     0.873947     0.887248
# 6      0.080751     0.654819     0.746914     0.933764
# 7      0.666961     0.455622     0.333377     0.656070
# 8      0.774070     0.413094     0.727295     0.498509
# 9      0.244770     0.327039     0.336744     0.122676

# %%
df5['Steve_grades'].plot.bar(stacked=True)
# or stacked=False. Makes no difference since we only selecting one column
df5['Steve_grades'].plot.bar(stacked=False)
# Out:
# <AxesSubplot:>

# %%
df6 = pd.DataFrame(3 * np.random.rand(4), index=['steve', 'john', 'mary', 'paul'], columns=['x'])
df6.plot.pie(subplots=True)

# Subplots needs to be true
# Out:
# array([<AxesSubplot:ylabel='x'>], dtype=object)

# %% [markdown]
# # Python Data Analysis Project Instructions
#
# * Download Anaconda if you have not already so you can use Jupyter Notebook
#
# Find a dataset of your interest from Tableau Public,  [Kaggle](https://www.kaggle.com/datasets/ruchi798/data-science-job-salaries?resource=download),  or Google Dataset Search and import it into python using one of the pandas functions (read_csv, read_excel)
#
# * Think of 2-3 business questions that you’d like to answer using the data
# * Write the code and document your steps in a Jupyter notebook to accomplish the following:
#     * Load your data
#     * Clean your data for analysis and get it into DataFrames
# * Demonstrate the following in your notebook:
#     * Ability to index DataFrames
#     * Ability to view column headers, first n rows, and last n rows in a DataFrame
#     * Ability to select specific data points from a DataFrame
#     * Ability to sort DataFrames
#     * Ability to summarize DataFrames using GroupBy
#     * Ability to run basic descriptive statistics on a DataFrame
#     * Ability to build a basic chart with DataFrames with plot()
# * Run a basic data analysis to find at least two interesting insights and describe why they are useful
# * You should call out the code that produces these insights, as well as a visual representation of the insights (visualization, table, number, etc.)
# * You should use comments/markup to describe the insight and why it’s important directly in the Jupyter Notebook
#
# ### Submission
# * Post your code on Github
# * Present your analysis and findings directly from your Jupyter Notebook
# * Create 3-5 minutes of a recorded video presentation (using [Loom](https://www.loom.com/) that explains your final project (business questions, dataset, overview of your code, insights, and visuals). Your video should not go over 5 minutes. Create a succinct video that can effectively communicate your message in a short time to busy business users.

# %% [markdown]
# ### More filtering Techniques

# %%
df.head()
# Out:
#         location  product_type product_description  quantity  price
# 0  Staten Island         seeds               daisy         4   6.99
# 1  Staten Island         seeds          calla lily        46  19.99
# 2  Staten Island         seeds              tomato        85  13.99
# 3  Staten Island  garden tools                rake         4  13.99
# 4  Staten Island  garden tools         wheelbarrow         0  89.99

# %%
data2 = df.query("product_type == 'seeds'")

# %%
data2['quantity'].mean()
# Out:
# 42.44444444444444

# %%
df.query("product_type == 'seeds' or product_type == 'garden tools'")
# Out:
#          location  product_type product_description  quantity  price
# 0   Staten Island         seeds               daisy         4   6.99
# 1   Staten Island         seeds          calla lily        46  19.99
# 2   Staten Island         seeds              tomato        85  13.99
# 3   Staten Island  garden tools                rake         4  13.99
# 4   Staten Island  garden tools         wheelbarrow         0  89.99
# 5   Staten Island  garden tools               spade        93  19.99
# 10       Brooklyn         seeds               daisy        50   6.99
# 11       Brooklyn         seeds          calla lily         0  19.99
# 12       Brooklyn         seeds              tomato         0  13.99
# 13       Brooklyn  garden tools                rake        15  13.99
# 14       Brooklyn  garden tools         wheelbarrow        82  89.99
# 15       Brooklyn  garden tools               spade        36  19.99
# 20         Queens         seeds               daisy        57   6.99
# 21         Queens         seeds          calla lily        95  19.99
# 22         Queens         seeds              tomato        45  13.99
# 23         Queens  garden tools                rake        21  13.99
# 24         Queens  garden tools         wheelbarrow        98  89.99
# 25         Queens  garden tools               spade        26  19.99

# %%
some_subset = df.query("product_type == 'seeds' and price == 6.99")
# Out:
#          location product_type product_description  quantity  price
# 0   Staten Island        seeds               daisy         4   6.99
# 10       Brooklyn        seeds               daisy        50   6.99
# 20         Queens        seeds               daisy        57   6.99

# %%
some_subset
# Out:
#          location product_type product_description  quantity  price
# 0   Staten Island        seeds               daisy         4   6.99
# 10       Brooklyn        seeds               daisy        50   6.99
# 20         Queens        seeds               daisy        57   6.99

# %%
some_subset['quantity'].mean()
# Out:
# 37.0

# %%
some_subset['quantity'].plot.hist(bins = 20)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df.head(5)
# Out:
#         location  product_type product_description  quantity  price
# 0  Staten Island         seeds               daisy         4   6.99
# 1  Staten Island         seeds          calla lily        46  19.99
# 2  Staten Island         seeds              tomato        85  13.99
# 3  Staten Island  garden tools                rake         4  13.99
# 4  Staten Island  garden tools         wheelbarrow         0  89.99

# %%
with_price_gone = df.drop(columns = ['price'])
with_price_gone
# Out:
#          location  product_type         product_description  quantity
# 0   Staten Island         seeds                       daisy         4
# 1   Staten Island         seeds                  calla lily        46
# 2   Staten Island         seeds                      tomato        85
# 3   Staten Island  garden tools                        rake         4
# 4   Staten Island  garden tools                 wheelbarrow         0
# 5   Staten Island  garden tools                       spade        93
# 6   Staten Island  pest_control               insect killer        74
# 7   Staten Island  pest_control                 weed killer         8
# 8   Staten Island       planter  20 inch terracotta planter         0
# 9   Staten Island       planter      8 inch plastic planter        53
# 10       Brooklyn         seeds                       daisy        50
# 11       Brooklyn         seeds                  calla lily         0
# 12       Brooklyn         seeds                      tomato         0
# 13       Brooklyn  garden tools                        rake        15
# 14       Brooklyn  garden tools                 wheelbarrow        82
# 15       Brooklyn  garden tools                       spade        36
# 16       Brooklyn  pest_control               insect killer        80
# 17       Brooklyn  pest_control                 weed killer        76
# 18       Brooklyn       planter  20 inch terracotta planter         5
# 19       Brooklyn       planter      8 inch plastic planter        26
# 20         Queens         seeds                       daisy        57
# 21         Queens         seeds                  calla lily        95
# 22         Queens         seeds                      tomato        45
# 23         Queens  garden tools                        rake        21
# 24         Queens  garden tools                 wheelbarrow        98
# 25         Queens  garden tools                       spade        26
# 26         Queens  pest_control               insect killer         0
# 27         Queens  pest_control                 weed killer        16
# 28         Queens       planter  20 inch terracotta planter        87

# %%
df
# Out:
#          location  product_type         product_description  quantity  price
# 0   Staten Island         seeds                       daisy         4   6.99
# 1   Staten Island         seeds                  calla lily        46  19.99
# 2   Staten Island         seeds                      tomato        85  13.99
# 3   Staten Island  garden tools                        rake         4  13.99
# 4   Staten Island  garden tools                 wheelbarrow         0  89.99
# 5   Staten Island  garden tools                       spade        93  19.99
# 6   Staten Island  pest_control               insect killer        74  12.99
# 7   Staten Island  pest_control                 weed killer         8  23.99
# 8   Staten Island       planter  20 inch terracotta planter         0  17.99
# 9   Staten Island       planter      8 inch plastic planter        53   3.99
# 10       Brooklyn         seeds                       daisy        50   6.99
# 11       Brooklyn         seeds                  calla lily         0  19.99
# 12       Brooklyn         seeds                      tomato         0  13.99
# 13       Brooklyn  garden tools                        rake        15  13.99
# 14       Brooklyn  garden tools                 wheelbarrow        82  89.99
# 15       Brooklyn  garden tools                       spade        36  19.99
# 16       Brooklyn  pest_control               insect killer        80  12.99
# 17       Brooklyn  pest_control                 weed killer        76  23.99
# 18       Brooklyn       planter  20 inch terracotta planter         5  17.99
# 19       Brooklyn       planter      8 inch plastic planter        26   3.99
# 20         Queens         seeds                       daisy        57   6.99
# 21         Queens         seeds                  calla lily        95  19.99
# 22         Queens         seeds                      tomato        45  13.99
# 23         Queens  garden tools                        rake        21  13.99
# 24         Queens  garden tools                 wheelbarrow        98  89.99
# 25         Queens  garden tools                       spade        26  19.99
# 26         Queens  pest_control               insect killer         0  12.99
# 27         Queens  pest_control                 weed killer        16  23.99
# 28         Queens       planter  20 inch terracotta planter        87  17.99

# %%
import pandas as pd
  
# creating and initializing a list
values= [['Rohan',455],['Elvish',250],['Deepak',495],
         ['Soni',400],['Radhika',350],['Vansh',450]]
 
# creating a pandas dataframe
df = pd.DataFrame(values,columns=['Name','Total_Marks'])
 
# Applying lambda function to find
# percentage of 'Total_Marks' column
# using df.assign()
df = df.assign(Percentage = lambda x: (x['Total_Marks'] /500 * 100))
 
# displaying the data frame
df
# Out:
#       Name  Total_Marks  Percentage
# 0    Rohan          455        91.0
# 1   Elvish          250        50.0
# 2   Deepak          495        99.0
# 3     Soni          400        80.0
# 4  Radhika          350        70.0
# 5    Vansh          450        90.0
